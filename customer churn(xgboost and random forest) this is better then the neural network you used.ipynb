# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/Churn_Modelling.csv')

# Display the first few rows of the dataset to understand its structure
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# One-hot encode the categorical variables
df = pd.get_dummies(df, columns=['Geography', 'Gender'], drop_first=True)

# Drop unnecessary columns
X = df.drop(columns=['RowNumber', 'CustomerId', 'Surname', 'Exited'])
y = df['Exited']

df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Age  Tenure    Balance  \
# 0          1    15634602  Hargrave          619   42       2       0.00
# 1          2    15647311      Hill          608   41       1   83807.86
# 2          3    15619304      Onio          502   42       8  159660.80
# 3          4    15701354      Boni          699   39       1       0.00
# 4          5    15737888  Mitchell          850   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    Geography_Germany  Geography_Spain  Gender_Male
# 0              False            False        False
# 1              False             True        False
# 2              False            False        False
# 3              False            False        False
# 4              False             True        False

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Initialize the scaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform both training and test data
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Initialize and train the Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Predict on the training and testing sets
rf_train_preds = rf_model.predict(X_train)
rf_test_preds = rf_model.predict(X_test)

# Calculate training and testing accuracy
rf_train_accuracy = accuracy_score(y_train, rf_train_preds)
rf_test_accuracy = accuracy_score(y_test, rf_test_preds)

print(f"Random Forest Training Accuracy: {rf_train_accuracy:.4f}")
print(f"Random Forest Testing Accuracy: {rf_test_accuracy:.4f}")
# Out:
# Random Forest Training Accuracy: 1.0000
# Random Forest Testing Accuracy: 0.8670

# %%
from xgboost import XGBClassifier

# Initialize and train the XGBoost model
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
xgb_model.fit(X_train, y_train)

# Predict on the training and testing sets
xgb_train_preds = xgb_model.predict(X_train)
xgb_test_preds = xgb_model.predict(X_test)

# Calculate training and testing accuracy
xgb_train_accuracy = accuracy_score(y_train, xgb_train_preds)
xgb_test_accuracy = accuracy_score(y_test, xgb_test_preds)

print(f"XGBoost Training Accuracy: {xgb_train_accuracy:.4f}")
print(f"XGBoost Testing Accuracy: {xgb_test_accuracy:.4f}")
# Out:
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [09:48:39] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost Training Accuracy: 0.9585
# XGBoost Testing Accuracy: 0.8640

# %%
###even if you tune your hyper parameters manually it still shows the same


from xgboost import XGBClassifier

# Initialize and train the XGBoost model with regularization and early stopping
xgb_model1 = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42,
                          reg_lambda=2.0, reg_alpha=1.0, max_depth=2, min_child_weight=10,
                          subsample=0.8, colsample_bytree=0.8, learning_rate=0.01, n_estimators=500)

xgb_model1.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=True)





# Predict on the training and testing sets
xgb_train_preds1 = xgb_model.predict(X_train)
xgb_test_preds1 = xgb_model.predict(X_test)

# Calculate training and testing accuracy
xgb_train_accuracy = accuracy_score(y_train, xgb_train_preds1)
xgb_test_accuracy = accuracy_score(y_test, xgb_test_preds1)

print(f"XGBoost Training Accuracy: {xgb_train_accuracy:.4f}")
print(f"XGBoost Testing Accuracy: {xgb_test_accuracy:.4f}")
# Out:
# [0]	validation_0-logloss:0.49801
# [1]	validation_0-logloss:0.49672
# [2]	validation_0-logloss:0.49542
# [3]	validation_0-logloss:0.49415
# [4]	validation_0-logloss:0.49228
# [5]	validation_0-logloss:0.49076
# [6]	validation_0-logloss:0.48905
# [7]	validation_0-logloss:0.48740
# [8]	validation_0-logloss:0.48622
# [9]	validation_0-logloss:0.48468
# [10]	validation_0-logloss:0.48307
# [11]	validation_0-logloss:0.48170
# [12]	validation_0-logloss:0.48018
# [13]	validation_0-logloss:0.47868
# [14]	validation_0-logloss:0.47762
# [15]	validation_0-logloss:0.47658
# [16]	validation_0-logloss:0.47530
# [17]	validation_0-logloss:0.47400
# [18]	validation_0-logloss:0.47277
# [19]	validation_0-logloss:0.47160
# [20]	validation_0-logloss:0.47060
# [21]	validation_0-logloss:0.46938
# [22]	validation_0-logloss:0.46820
# [23]	validation_0-logloss:0.46726
# [24]	validation_0-logloss:0.46597
# [25]	validation_0-logloss:0.46484
# [26]	validation_0-logloss:0.46392
# [27]	validation_0-logloss:0.46276
# [28]	validation_0-logloss:0.46186
# [29]	validation_0-logloss:0.46098
# [30]	validation_0-logloss:0.46013
# [31]	validation_0-logloss:0.45929
# [32]	validation_0-logloss:0.45845
# [33]	validation_0-logloss:0.45737
# [34]	validation_0-logloss:0.45623
# [35]	validation_0-logloss:0.45517
# [36]	validation_0-logloss:0.45438
# [37]	validation_0-logloss:0.45336
# [38]	validation_0-logloss:0.45227
# [39]	validation_0-logloss:0.45143
# [40]	validation_0-logloss:0.45039
# [41]	validation_0-logloss:0.44995
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:158: UserWarning: [09:59:59] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [42]	validation_0-logloss:0.44893
# [43]	validation_0-logloss:0.44790
# [44]	validation_0-logloss:0.44690
# [45]	validation_0-logloss:0.44647
# [46]	validation_0-logloss:0.44561
# [47]	validation_0-logloss:0.44518
# [48]	validation_0-logloss:0.44429
# [49]	validation_0-logloss:0.44333
# [50]	validation_0-logloss:0.44256
# [51]	validation_0-logloss:0.44167
# [52]	validation_0-logloss:0.44095
# [53]	validation_0-logloss:0.44025
# [54]	validation_0-logloss:0.43935
# [55]	validation_0-logloss:0.43850
# [56]	validation_0-logloss:0.43783
# [57]	validation_0-logloss:0.43716
# [58]	validation_0-logloss:0.43643
# [59]	validation_0-logloss:0.43575
# [60]	validation_0-logloss:0.43494
# [61]	validation_0-logloss:0.43430
# [62]	validation_0-logloss:0.43361
# [63]	validation_0-logloss:0.43295
# [64]	validation_0-logloss:0.43229
# [65]	validation_0-logloss:0.43160
# [66]	validation_0-logloss:0.43088
# [67]	validation_0-logloss:0.43018
# [68]	validation_0-logloss:0.42950
# [69]	validation_0-logloss:0.42887
# [70]	validation_0-logloss:0.42814
# [71]	validation_0-logloss:0.42747
# [72]	validation_0-logloss:0.42686
# [73]	validation_0-logloss:0.42626
# [74]	validation_0-logloss:0.42569
# [75]	validation_0-logloss:0.42512
# [76]	validation_0-logloss:0.42445
# [77]	validation_0-logloss:0.42380
# [78]	validation_0-logloss:0.42324
# [79]	validation_0-logloss:0.42268
# [80]	validation_0-logloss:0.42212
# [81]	validation_0-logloss:0.42177
# [82]	validation_0-logloss:0.42120
# [83]	validation_0-logloss:0.42061
# [84]	validation_0-logloss:0.42008
# [85]	validation_0-logloss:0.41950
# [86]	validation_0-logloss:0.41898
# [87]	validation_0-logloss:0.41849
# [88]	validation_0-logloss:0.41802
# [89]	validation_0-logloss:0.41752
# [90]	validation_0-logloss:0.41701
# [91]	validation_0-logloss:0.41650
# [92]	validation_0-logloss:0.41595
# [93]	validation_0-logloss:0.41540
# [94]	validation_0-logloss:0.41485
# [95]	validation_0-logloss:0.41433
# [96]	validation_0-logloss:0.41386
# [97]	validation_0-logloss:0.41335
# [98]	validation_0-logloss:0.41282
# [99]	validation_0-logloss:0.41233
# [100]	validation_0-logloss:0.41180
# [101]	validation_0-logloss:0.41147
# [102]	validation_0-logloss:0.41097
# [103]	validation_0-logloss:0.41053
# [104]	validation_0-logloss:0.41002
# [105]	validation_0-logloss:0.40953
# [106]	validation_0-logloss:0.40922
# [107]	validation_0-logloss:0.40882
# [108]	validation_0-logloss:0.40835
# [109]	validation_0-logloss:0.40793
# [110]	validation_0-logloss:0.40753
# [111]	validation_0-logloss:0.40710
# [112]	validation_0-logloss:0.40650
# [113]	validation_0-logloss:0.40603
# [114]	validation_0-logloss:0.40558
# [115]	validation_0-logloss:0.40517
# [116]	validation_0-logloss:0.40480
# [117]	validation_0-logloss:0.40437
# [118]	validation_0-logloss:0.40395
# [119]	validation_0-logloss:0.40355
# [120]	validation_0-logloss:0.40311
# [121]	validation_0-logloss:0.40269
# [122]	validation_0-logloss:0.40232
# [123]	validation_0-logloss:0.40195
# [124]	validation_0-logloss:0.40167
# [125]	validation_0-logloss:0.40132
# [126]	validation_0-logloss:0.40093
# [127]	validation_0-logloss:0.40057
# [128]	validation_0-logloss:0.40027
# [129]	validation_0-logloss:0.39995
# [130]	validation_0-logloss:0.39959
# [131]	validation_0-logloss:0.39923
# [132]	validation_0-logloss:0.39884
# [133]	validation_0-logloss:0.39851
# [134]	validation_0-logloss:0.39821
# [135]	validation_0-logloss:0.39787
# [136]	validation_0-logloss:0.39734
# [137]	validation_0-logloss:0.39704
# [138]	validation_0-logloss:0.39669
# [139]	validation_0-logloss:0.39630
# [140]	validation_0-logloss:0.39590
# [141]	validation_0-logloss:0.39555
# [142]	validation_0-logloss:0.39525
# [143]	validation_0-logloss:0.39475
# [144]	validation_0-logloss:0.39448
# [145]	validation_0-logloss:0.39416
# [146]	validation_0-logloss:0.39386
# [147]	validation_0-logloss:0.39369
# [148]	validation_0-logloss:0.39333
# [149]	validation_0-logloss:0.39305
# [150]	validation_0-logloss:0.39282
# [151]	validation_0-logloss:0.39245
# [152]	validation_0-logloss:0.39228
# [153]	validation_0-logloss:0.39192
# [154]	validation_0-logloss:0.39156
# [155]	validation_0-logloss:0.39123
# [156]	validation_0-logloss:0.39095
# [157]	validation_0-logloss:0.39065
# [158]	validation_0-logloss:0.39020
# [159]	validation_0-logloss:0.38990
# [160]	validation_0-logloss:0.38958
# [161]	validation_0-logloss:0.38930
# [162]	validation_0-logloss:0.38903
# [163]	validation_0-logloss:0.38871
# [164]	validation_0-logloss:0.38843
# [165]	validation_0-logloss:0.38816
# [166]	validation_0-logloss:0.38791
# [167]	validation_0-logloss:0.38764
# [168]	validation_0-logloss:0.38734
# [169]	validation_0-logloss:0.38711
# [170]	validation_0-logloss:0.38680
# [171]	validation_0-logloss:0.38652
# [172]	validation_0-logloss:0.38625
# [173]	validation_0-logloss:0.38602
# [174]	validation_0-logloss:0.38576
# [175]	validation_0-logloss:0.38547
# [176]	validation_0-logloss:0.38517
# [177]	validation_0-logloss:0.38494
# [178]	validation_0-logloss:0.38471
# [179]	validation_0-logloss:0.38448
# [180]	validation_0-logloss:0.38428
# [181]	validation_0-logloss:0.38405
# [182]	validation_0-logloss:0.38380
# [183]	validation_0-logloss:0.38352
# [184]	validation_0-logloss:0.38332
# [185]	validation_0-logloss:0.38304
# [186]	validation_0-logloss:0.38284
# [187]	validation_0-logloss:0.38263
# [188]	validation_0-logloss:0.38235
# [189]	validation_0-logloss:0.38209
# [190]	validation_0-logloss:0.38183
# [191]	validation_0-logloss:0.38161
# [192]	validation_0-logloss:0.38134
# [193]	validation_0-logloss:0.38099
# [194]	validation_0-logloss:0.38065
# [195]	validation_0-logloss:0.38045
# [196]	validation_0-logloss:0.38019
# [197]	validation_0-logloss:0.37996
# [198]	validation_0-logloss:0.37972
# [199]	validation_0-logloss:0.37947
# [200]	validation_0-logloss:0.37924
# [201]	validation_0-logloss:0.37902
# [202]	validation_0-logloss:0.37884
# [203]	validation_0-logloss:0.37862
# [204]	validation_0-logloss:0.37843
# [205]	validation_0-logloss:0.37819
# [206]	validation_0-logloss:0.37800
# [207]	validation_0-logloss:0.37779
# [208]	validation_0-logloss:0.37759
# [209]	validation_0-logloss:0.37737
# [210]	validation_0-logloss:0.37721
# [211]	validation_0-logloss:0.37701
# [212]	validation_0-logloss:0.37679
# [213]	validation_0-logloss:0.37659
# [214]	validation_0-logloss:0.37639
# [215]	validation_0-logloss:0.37616
# [216]	validation_0-logloss:0.37596
# [217]	validation_0-logloss:0.37579
# [218]	validation_0-logloss:0.37559
# [219]	validation_0-logloss:0.37543
# [220]	validation_0-logloss:0.37525
# [221]	validation_0-logloss:0.37504
# [222]	validation_0-logloss:0.37487
# [223]	validation_0-logloss:0.37471
# [224]	validation_0-logloss:0.37450
# [225]	validation_0-logloss:0.37430
# [226]	validation_0-logloss:0.37413
# [227]	validation_0-logloss:0.37394
# [228]	validation_0-logloss:0.37379
# [229]	validation_0-logloss:0.37361
# [230]	validation_0-logloss:0.37339
# [231]	validation_0-logloss:0.37318
# [232]	validation_0-logloss:0.37300
# [233]	validation_0-logloss:0.37285
# [234]	validation_0-logloss:0.37265
# [235]	validation_0-logloss:0.37251
# [236]	validation_0-logloss:0.37234
# [237]	validation_0-logloss:0.37216
# [238]	validation_0-logloss:0.37193
# [239]	validation_0-logloss:0.37174
# [240]	validation_0-logloss:0.37155
# [241]	validation_0-logloss:0.37136
# [242]	validation_0-logloss:0.37115
# [243]	validation_0-logloss:0.37100
# [244]	validation_0-logloss:0.37086
# [245]	validation_0-logloss:0.37069
# [246]	validation_0-logloss:0.37051
# [247]	validation_0-logloss:0.37038
# [248]	validation_0-logloss:0.37019
# [249]	validation_0-logloss:0.37005
# [250]	validation_0-logloss:0.36987
# [251]	validation_0-logloss:0.36970
# [252]	validation_0-logloss:0.36957
# [253]	validation_0-logloss:0.36941
# [254]	validation_0-logloss:0.36924
# [255]	validation_0-logloss:0.36911
# [256]	validation_0-logloss:0.36895
# [257]	validation_0-logloss:0.36874
# [258]	validation_0-logloss:0.36851
# [259]	validation_0-logloss:0.36830
# [260]	validation_0-logloss:0.36818
# [261]	validation_0-logloss:0.36797
# [262]	validation_0-logloss:0.36780
# [263]	validation_0-logloss:0.36764
# [264]	validation_0-logloss:0.36748
# [265]	validation_0-logloss:0.36735
# [266]	validation_0-logloss:0.36719
# [267]	validation_0-logloss:0.36703
# [268]	validation_0-logloss:0.36687
# [269]	validation_0-logloss:0.36672
# [270]	validation_0-logloss:0.36657
# [271]	validation_0-logloss:0.36642
# [272]	validation_0-logloss:0.36629
# [273]	validation_0-logloss:0.36616
# [274]	validation_0-logloss:0.36603
# [275]	validation_0-logloss:0.36589
# [276]	validation_0-logloss:0.36576
# [277]	validation_0-logloss:0.36563
# [278]	validation_0-logloss:0.36553
# [279]	validation_0-logloss:0.36539
# [280]	validation_0-logloss:0.36525
# [281]	validation_0-logloss:0.36508
# [282]	validation_0-logloss:0.36497
# [283]	validation_0-logloss:0.36482
# [284]	validation_0-logloss:0.36470
# [285]	validation_0-logloss:0.36456
# [286]	validation_0-logloss:0.36444
# [287]	validation_0-logloss:0.36434
# [288]	validation_0-logloss:0.36421
# [289]	validation_0-logloss:0.36405
# [290]	validation_0-logloss:0.36385
# [291]	validation_0-logloss:0.36374
# [292]	validation_0-logloss:0.36360
# [293]	validation_0-logloss:0.36346
# [294]	validation_0-logloss:0.36338
# [295]	validation_0-logloss:0.36325
# [296]	validation_0-logloss:0.36315
# [297]	validation_0-logloss:0.36303
# [298]	validation_0-logloss:0.36293
# [299]	validation_0-logloss:0.36279
# [300]	validation_0-logloss:0.36266
# [301]	validation_0-logloss:0.36249
# [302]	validation_0-logloss:0.36236
# [303]	validation_0-logloss:0.36224
# [304]	validation_0-logloss:0.36207
# [305]	validation_0-logloss:0.36189
# [306]	validation_0-logloss:0.36180
# [307]	validation_0-logloss:0.36170
# [308]	validation_0-logloss:0.36154
# [309]	validation_0-logloss:0.36144
# [310]	validation_0-logloss:0.36134
# [311]	validation_0-logloss:0.36122
# [312]	validation_0-logloss:0.36110
# [313]	validation_0-logloss:0.36099
# [314]	validation_0-logloss:0.36091
# [315]	validation_0-logloss:0.36080
# [316]	validation_0-logloss:0.36067
# [317]	validation_0-logloss:0.36058
# [318]	validation_0-logloss:0.36045
# [319]	validation_0-logloss:0.36034
# [320]	validation_0-logloss:0.36026
# [321]	validation_0-logloss:0.36013
# [322]	validation_0-logloss:0.36004
# [323]	validation_0-logloss:0.35995
# [324]	validation_0-logloss:0.35984
# [325]	validation_0-logloss:0.35974
# [326]	validation_0-logloss:0.35963
# [327]	validation_0-logloss:0.35954
# [328]	validation_0-logloss:0.35943
# [329]	validation_0-logloss:0.35934
# [330]	validation_0-logloss:0.35924
# [331]	validation_0-logloss:0.35913
# [332]	validation_0-logloss:0.35903
# [333]	validation_0-logloss:0.35893
# [334]	validation_0-logloss:0.35879
# [335]	validation_0-logloss:0.35871
# [336]	validation_0-logloss:0.35861
# [337]	validation_0-logloss:0.35848
# [338]	validation_0-logloss:0.35840
# [339]	validation_0-logloss:0.35832
# [340]	validation_0-logloss:0.35820
# [341]	validation_0-logloss:0.35811
# [342]	validation_0-logloss:0.35797
# [343]	validation_0-logloss:0.35790
# [344]	validation_0-logloss:0.35780
# [345]	validation_0-logloss:0.35772
# [346]	validation_0-logloss:0.35759
# [347]	validation_0-logloss:0.35750
# [348]	validation_0-logloss:0.35741
# [349]	validation_0-logloss:0.35727
# [350]	validation_0-logloss:0.35718
# [351]	validation_0-logloss:0.35711
# [352]	validation_0-logloss:0.35700
# [353]	validation_0-logloss:0.35691
# [354]	validation_0-logloss:0.35683
# [355]	validation_0-logloss:0.35669
# [356]	validation_0-logloss:0.35656
# [357]	validation_0-logloss:0.35649
# [358]	validation_0-logloss:0.35640
# [359]	validation_0-logloss:0.35627
# [360]	validation_0-logloss:0.35619
# [361]	validation_0-logloss:0.35611
# [362]	validation_0-logloss:0.35602
# [363]	validation_0-logloss:0.35589
# [364]	validation_0-logloss:0.35580
# [365]	validation_0-logloss:0.35568
# [366]	validation_0-logloss:0.35559
# [367]	validation_0-logloss:0.35550
# [368]	validation_0-logloss:0.35534
# [369]	validation_0-logloss:0.35524
# [370]	validation_0-logloss:0.35517
# [371]	validation_0-logloss:0.35501
# [372]	validation_0-logloss:0.35493
# [373]	validation_0-logloss:0.35484
# [374]	validation_0-logloss:0.35470
# [375]	validation_0-logloss:0.35460
# [376]	validation_0-logloss:0.35453
# [377]	validation_0-logloss:0.35445
# [378]	validation_0-logloss:0.35440
# [379]	validation_0-logloss:0.35431
# [380]	validation_0-logloss:0.35420
# [381]	validation_0-logloss:0.35412
# [382]	validation_0-logloss:0.35400
# [383]	validation_0-logloss:0.35384
# [384]	validation_0-logloss:0.35378
# [385]	validation_0-logloss:0.35367
# [386]	validation_0-logloss:0.35356
# [387]	validation_0-logloss:0.35348
# [388]	validation_0-logloss:0.35343
# [389]	validation_0-logloss:0.35338
# [390]	validation_0-logloss:0.35333
# [391]	validation_0-logloss:0.35323
# [392]	validation_0-logloss:0.35312
# [393]	validation_0-logloss:0.35307
# [394]	validation_0-logloss:0.35295
# [395]	validation_0-logloss:0.35289
# [396]	validation_0-logloss:0.35282
# [397]	validation_0-logloss:0.35276
# [398]	validation_0-logloss:0.35270
# [399]	validation_0-logloss:0.35262
# [400]	validation_0-logloss:0.35253
# [401]	validation_0-logloss:0.35246
# [402]	validation_0-logloss:0.35240
# [403]	validation_0-logloss:0.35229
# [404]	validation_0-logloss:0.35222
# [405]	validation_0-logloss:0.35215
# [406]	validation_0-logloss:0.35209
# [407]	validation_0-logloss:0.35202
# [408]	validation_0-logloss:0.35197
# [409]	validation_0-logloss:0.35187
# [410]	validation_0-logloss:0.35181
# [411]	validation_0-logloss:0.35173
# [412]	validation_0-logloss:0.35163
# [413]	validation_0-logloss:0.35153
# [414]	validation_0-logloss:0.35147
# [415]	validation_0-logloss:0.35141
# [416]	validation_0-logloss:0.35131
# [417]	validation_0-logloss:0.35124
# [418]	validation_0-logloss:0.35117
# [419]	validation_0-logloss:0.35110
# [420]	validation_0-logloss:0.35105
# [421]	validation_0-logloss:0.35101
# [422]	validation_0-logloss:0.35090
# [423]	validation_0-logloss:0.35084
# [424]	validation_0-logloss:0.35077
# [425]	validation_0-logloss:0.35071
# [426]	validation_0-logloss:0.35064
# [427]	validation_0-logloss:0.35058
# [428]	validation_0-logloss:0.35052
# [429]	validation_0-logloss:0.35046
# [430]	validation_0-logloss:0.35040
# [431]	validation_0-logloss:0.35034
# [432]	validation_0-logloss:0.35029
# [433]	validation_0-logloss:0.35018
# [434]	validation_0-logloss:0.35009
# [435]	validation_0-logloss:0.35003
# [436]	validation_0-logloss:0.34997
# [437]	validation_0-logloss:0.34988
# [438]	validation_0-logloss:0.34978
# [439]	validation_0-logloss:0.34969
# [440]	validation_0-logloss:0.34962
# [441]	validation_0-logloss:0.34956
# [442]	validation_0-logloss:0.34950
# [443]	validation_0-logloss:0.34944
# [444]	validation_0-logloss:0.34941
# [445]	validation_0-logloss:0.34935
# [446]	validation_0-logloss:0.34931
# [447]	validation_0-logloss:0.34927
# [448]	validation_0-logloss:0.34923
# [449]	validation_0-logloss:0.34920
# [450]	validation_0-logloss:0.34915
# [451]	validation_0-logloss:0.34909
# [452]	validation_0-logloss:0.34904
# [453]	validation_0-logloss:0.34898
# [454]	validation_0-logloss:0.34893
# [455]	validation_0-logloss:0.34885
# [456]	validation_0-logloss:0.34881
# [457]	validation_0-logloss:0.34875
# [458]	validation_0-logloss:0.34870
# [459]	validation_0-logloss:0.34863
# [460]	validation_0-logloss:0.34858
# [461]	validation_0-logloss:0.34849
# [462]	validation_0-logloss:0.34843
# [463]	validation_0-logloss:0.34838
# [464]	validation_0-logloss:0.34832
# [465]	validation_0-logloss:0.34827
# [466]	validation_0-logloss:0.34817
# [467]	validation_0-logloss:0.34815
# [468]	validation_0-logloss:0.34810
# [469]	validation_0-logloss:0.34796
# [470]	validation_0-logloss:0.34793
# [471]	validation_0-logloss:0.34788
# [472]	validation_0-logloss:0.34783
# [473]	validation_0-logloss:0.34772
# [474]	validation_0-logloss:0.34766
# [475]	validation_0-logloss:0.34761
# [476]	validation_0-logloss:0.34757
# [477]	validation_0-logloss:0.34752
# [478]	validation_0-logloss:0.34743
# [479]	validation_0-logloss:0.34739
# [480]	validation_0-logloss:0.34737
# [481]	validation_0-logloss:0.34735
# [482]	validation_0-logloss:0.34730
# [483]	validation_0-logloss:0.34725
# [484]	validation_0-logloss:0.34720
# [485]	validation_0-logloss:0.34712
# [486]	validation_0-logloss:0.34702
# [487]	validation_0-logloss:0.34698
# [488]	validation_0-logloss:0.34695
# [489]	validation_0-logloss:0.34692
# [490]	validation_0-logloss:0.34684
# [491]	validation_0-logloss:0.34682
# [492]	validation_0-logloss:0.34677
# [493]	validation_0-logloss:0.34667
# [494]	validation_0-logloss:0.34663
# [495]	validation_0-logloss:0.34656
# [496]	validation_0-logloss:0.34653
# [497]	validation_0-logloss:0.34645
# [498]	validation_0-logloss:0.34639
# [499]	validation_0-logloss:0.34635
# XGBoost Training Accuracy: 0.9585
# XGBoost Testing Accuracy: 0.8640

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBClassifier

# Define the parameter grid to search
param_grid = {
    'max_depth': [2, 3, 4],
    'min_child_weight': [1, 5, 10],
    'reg_lambda': [1.0, 2.0, 3.0],
    'reg_alpha': [0.0, 0.5, 1.0],
    'learning_rate': [0.01, 0.1],
    'n_estimators': [100, 200, 500],
    'subsample': [0.8, 1.0],
    'colsample_bytree': [0.8, 1.0]
}

# Initialize the XGBoost model
xgb_model2 = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)

# Set up Grid Search with 5-fold cross-validation
grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid,
                           cv=5, scoring='accuracy', verbose=1, n_jobs=-1)

# Fit the model
grid_search.fit(X_train, y_train)

# Best parameters found by Grid Search
print("Best Hyperparameters:", grid_search.best_params_)

# Predict using the best model from grid search
best_xgb_model = grid_search.best_estimator_
best_xgb_train_preds = best_xgb_model.predict(X_train)
best_xgb_test_preds = best_xgb_model.predict(X_test)

# Calculate training and testing accuracy
best_xgb_train_accuracy = accuracy_score(y_train, best_xgb_train_preds)
best_xgb_test_accuracy = accuracy_score(y_test, best_xgb_test_preds)

print(f"Best XGBoost Training Accuracy: {best_xgb_train_accuracy:.4f}")
print(f"Best XGBoost Testing Accuracy: {best_xgb_test_accuracy:.4f}")
# Out:
# Fitting 5 folds for each of 1944 candidates, totalling 9720 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-c0544b869ec9> in <cell line: 24>()
#      22
#      23 # Fit the model
# ---> 24 grid_search.fit(X_train, y_train)
#      25
#      26 # Best parameters found by Grid Search
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     896                 return results
#     897
# --> 898             self._run_search(evaluate_candidates)
#     899
#     900             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1420     def _run_search(self, evaluate_candidates):
#    1421         """Search all candidates in param_grid"""
# -> 1422         evaluate_candidates(ParameterGrid(self.param_grid))
#    1423
#    1424
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     843                     )
#     844
# --> 845                 out = parallel(
#     846                     delayed(_fit_and_score)(
#     847                         clone(base_estimator),
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      63             for delayed_func, args, kwargs in iterable
#      64         )
# ---> 65         return super().__call__(iterable_with_config)
#      66
#      67
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    2005         next(output)
#    2006
# -> 2007         return output if self.return_generator else list(output)
#    2008
#    2009     def __repr__(self):
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1648
#    1649             with self._backend.retrieval_context():
# -> 1650                 yield from self._retrieve()
#    1651
#    1652         except GeneratorExit:
#
# /usr/local/lib/python3.10/dist-packages/joblib/parallel.py in _retrieve(self)
#    1760                 (self._jobs[0].get_status(
#    1761                     timeout=self.timeout) == TASK_PENDING)):
# -> 1762                 time.sleep(0.01)
#    1763                 continue
#    1764
#
# KeyboardInterrupt:
